# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Load the Dataset

# %%
df = pd.read_csv("C:\\Users\\patte\\Downloads\\archive.zip")

# %%
df
# Out:
#      PassengerId  Pclass               Name     Sex  Age  SibSp  Parch  \
# 0              1       3       Allison Hill    male   17      4      2
# 1              2       1        Noah Rhodes    male   60      2      2
# 2              3       3    Angie Henderson    male   64      0      0
# 3              4       3      Daniel Wagner    male   35      4      0
# 4              5       1    Cristian Santos  female   70      0      3
# ..           ...     ...                ...     ...  ...    ...    ...
# 995          996       2      Brittany Ward    male   69      2      3
# 996          997       2     Edward Stanley  female   61      4      4
# 997          998       3  Christina Johnson    male   10      4      1
# 998          999       3       Edgar Miller    male   50      3      2
# 999         1000       1  Elizabeth Sanders    male    3      3      3
#
#                                    Ticket    Fare Embarked  Survived
# ...

# %% [markdown]
# Display the First Rows

# %%
print("First 5 rows:")
print(df.head())
# Out:
# First 5 rows:
#    PassengerId  Pclass             Name     Sex  Age  SibSp  Parch  \
# 0            1       3     Allison Hill    male   17      4      2
# 1            2       1      Noah Rhodes    male   60      2      2
# 2            3       3  Angie Henderson    male   64      0      0
# 3            4       3    Daniel Wagner    male   35      4      0
# 4            5       1  Cristian Santos  female   70      0      3
#
#                                  Ticket    Fare Embarked  Survived
# 0  43d75413-a939-4bd1-a516-b0d47d3572cc  144.08        Q         1
# 1  6334fa2a-8b4b-47e7-a451-5ae01754bf08  249.04        S         0
# 2  61a66444-e2af-4629-9efb-336e2f546033   50.31        Q         1
# 3  0b6c03c8-721e-4419-afc3-e6495e911b91  235.20        C         1
# 4  436e3c49-770e-49db-b092-d40143675d58  160.17        C         1

# %% [markdown]
# Basic Info

# %%
print("\nData Info:")
print(df.info())
# Out:
# Data Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1000 non-null   int64
#  1   Pclass       1000 non-null   int64
#  2   Name         1000 non-null   object
#  3   Sex          1000 non-null   object
#  4   Age          1000 non-null   int64
#  5   SibSp        1000 non-null   int64
#  6   Parch        1000 non-null   int64
#  7   Ticket       1000 non-null   object
#  8   Fare         1000 non-null   float64
#  9   Embarked     1000 non-null   object
#  10  Survived     1000 non-null   int64
# dtypes: float64(1), int64(6), object(4)
# memory usage: 86.1+ KB
# None

# %% [markdown]
# Summary Statistics

# %%
print("\nSummary Statistics:")
print(df.describe(include='all'))
# Out:
# Summary Statistics:
#         PassengerId       Pclass            Name   Sex          Age  \
# count   1000.000000  1000.000000            1000  1000  1000.000000
# unique          NaN          NaN             995     2          NaN
# top             NaN          NaN  Michael Miller  male          NaN
# freq            NaN          NaN               2   527          NaN
# mean     500.500000     1.964000             NaN   NaN    38.458000
# std      288.819436     0.820596             NaN   NaN    23.103723
# min        1.000000     1.000000             NaN   NaN     1.000000
# 25%      250.750000     1.000000             NaN   NaN    19.000000
# 50%      500.500000     2.000000             NaN   NaN    36.500000
# 75%      750.250000     3.000000             NaN   NaN    59.000000
# max     1000.000000     3.000000             NaN   NaN    79.000000
#
#               SibSp        Parch                                Ticket  \
# ...

# %% [markdown]
# Check for missing Values

# %%
print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# PassengerId    0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# Survived       0
# dtype: int64

# %% [markdown]
# Data types and unique values

# %%
print("\nUnique Values per Column:")
for column in df.columns:
    print(f"{column}:{df[column].nunique()} unique values")
# Out:
# Unique Values per Column:
# PassengerId:1000 unique values
# Pclass:3 unique values
# Name:995 unique values
# Sex:2 unique values
# Age:79 unique values
# SibSp:5 unique values
# Parch:5 unique values
# Ticket:1000 unique values
# Fare:991 unique values
# Embarked:3 unique values
# Survived:2 unique values

# %% [markdown]
# Correlation matrix

# %%
print("\nCorrelation Matrix:")
print(df.corr(numeric_only=True))
# Out:
# Correlation Matrix:
#              PassengerId    Pclass       Age     SibSp     Parch      Fare  \
# PassengerId     1.000000 -0.028581 -0.060180  0.005650  0.051432 -0.014822
# Pclass         -0.028581  1.000000 -0.004145  0.000987 -0.005899  0.050952
# Age            -0.060180 -0.004145  1.000000  0.016709 -0.039179 -0.033666
# SibSp           0.005650  0.000987  0.016709  1.000000  0.013374  0.037322
# Parch           0.051432 -0.005899 -0.039179  0.013374  1.000000 -0.016533
# Fare           -0.014822  0.050952 -0.033666  0.037322 -0.016533  1.000000
# Survived       -0.008592  0.023685 -0.022637  0.034079 -0.063090 -0.018823
#
#              Survived
# PassengerId -0.008592
# Pclass       0.023685
# Age         -0.022637
# SibSp        0.034079
# Parch       -0.063090
# Fare        -0.018823
# Survived     1.000000

# %% [markdown]
# # Visualizations

# %%
# Set Style
sns.set(style="whitegrid")

# %% [markdown]
# Survival Count by Gender(Count Plot)

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=df,x='Sex',hue='Survived',palette='Set2')
plt.title('Survival Count by Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.legend(title='Survived',labels=['No','Yes'])
plt.tight_layout()
plt.show()

# %% [markdown]
# Survival Count by Passenger Class(Count Plot)

# %%
plt.figure(figsize=(6, 4))
sns.countplot(data=df, x='Pclass', hue='Survived', palette='Set1')
plt.title('Survival Count by Passenger Class')
plt.xlabel('Passenger Class')
plt.ylabel('Count')
plt.legend(title='Survived', labels=['No', 'Yes'])
plt.tight_layout()
plt.show()

# %% [markdown]
# HistoGram Plot

# %%
plt.figure(figsize=(8,4))
sns.histplot(data=df,x='Age',bins=30,kde=True,hue='Survived',element="step",palette='Set1')
plt.title('Age Distribution by Survival')
plt.tight_layout()
plt.show()

# %% [markdown]
# Box Plot

# %%
plt.figure(figsize=(8,4))
sns.boxplot(data=df,x='Survived',y='Fare',hue='Survived',palette='Set2')
plt.title('Fare Distribution by Survival')
plt.xticks([0, 1],['Not Survived','Survived'])
plt.tight_layout()
plt.show()

# %% [markdown]
# Scatter Plot

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(data=df,x='Age',y='Fare',hue='Survived',palette='Set1',alpha=0.7)
plt.title('Scatter Plot of Age vs Fare (Colored by Survival)')
plt.xlabel('Age')
plt.ylabel('Fare')
plt.legend(title='Survived')
plt.tight_layout()
plt.show()

# %% [markdown]
# Heat Map

# %%
plt.figure(figsize=(8, 6))
corr = df[['Pclass', 'Age', 'SibSp', 'Parch', 'Fare', 'Survived']].corr()
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.tight_layout()
plt.show()
